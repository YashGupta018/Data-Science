# %% [markdown]
# ![Image.jpeg](data:image/jpeg;base64,...)

# %%
s = "Yash Gupta"

print(s[-1])
print(s[-3])
print(s[3])
print(s[2:7])
print(s[2:7:1])
print(s[2:7:1])
print(s[2:7:2])
print(s[2:7:-1])
print(s[2:7:-2])
print(s[7:2:1])
print(s[7:2:-1])
print(s[7:2:-2])
# Out:
# a
# p
# h
# sh Gu
# sh Gu
# sh Gu
# s u
#
#
#
# puG h
# pGh
