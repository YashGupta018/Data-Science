# %% [markdown]
# # Daily Task - June 24, 2024

# %% [markdown]
# ### Ques. 1 : What will be the output of below code?
#     if i<j:
#         if j<k:
#             i=j
#         else:
#             j=k
#     else:
#         if j>k:
#             j=i
#         else:
#             i=k
#     print(i,j,k)
#
# ##### Print if the variables i,j,k have following values:<br>
#     a. i=3,j=5,k=7
#     b. i=-2,j=-5,k=9
#     c. i=8,j=15,k=12
#     d. i=13,j=15,k=13
#     e. i=3,j=5,k=17
# ##### Please solve first by using pen and paper so that the conditional statements concept will be clear and later code using jupyter, check if your answers are matching.

# %% [markdown]
# ![IMG_2104.jpg](data:image/jpeg;base64,...)

# %%
# Q1. What will be the output of below code?

# if i<j:
#     if j<k:
#         i=j
#     else:
#         j=k
# else:
#     if j>k:
#         j=i
#     else:
#         i=k
# print(i,j,k)

# Print if the variables i,j,k have following values:
# a. i=3,j=5,k=7
# b. i=-2,j=-5,k=9
# c. i=8,j=15,k=12
# d. i=13,j=15,k=13
# e. i=3,j=5,k=17

# Please solve first by using pen and paper so that the conditional statements concept will be clear and later code using jupyter, check if your answers are matching.

# Case a
i, j, k = 3, 5, 7
if i < j:
    if j < k:
        i = j
    else:
        j = k
else:
    if j > k:
        j = i
    else:
        i = k
print(i, j, k)

# Case b
i, j, k = -2, -5, 9
if i < j:
    if j < k:
        i = j
    else:
        j = k
else:
    if j > k:
        j = i
    else:
        i = k
print(i, j, k)

# Case c
i, j, k = 8, 15, 12
if i < j:
    if j < k:
        i = j
    else:
        j = k
else:
    if j > k:
        j = i
    else:
        i = k
print(i, j, k)

# Case d
i, j, k = 13, 15, 13
if i < j:
    if j < k:
        i = j
    else:
        j = k
else:
    if j > k:
        j = i
    else:
        i = k
print(i, j, k)

# Case e
i, j, k = 3, 5, 17
if i < j:
    if j < k:
        i = j
    else:
        j = k
else:
    if j > k:
        j = i
    else:
        i = k
print(i, j, k)
# Out:
# 5 5 7
# 9 -5 9
# 8 12 12
# 13 13 13
# 5 5 17

# %% [markdown]
# ### Ques. 2 : Using following list of cities per country :
#     - india = ["mumbai", "banglore", "chennai", "delhi"]
#     - pakistan = ["lahore","karachi","islamabad"]
#     - bangladesh = ["dhaka", "khulna", "rangpur"]
#
#     a. Write a program that asks user to enter a city name and it should tell which country the city belongs to
#     b. Write a program that asks the user to enter two cities and it tells you if they both are in the same country or not. For example if I enter mumbai and chennai, it will print "Both cities are in India" , but if I enter mumbai and dhaka it should print "They don't belong to the same country".

# %%
# a. Write a program that asks user to enter a city name and it should tell which country the city belongs to

india = ["mumbai", "banglore", "chennai", "delhi"]
pakistan = ["lahore", "karachi", "islamabad"]
bangladesh = ["dhaka", "khulna", "rangpur"]

# Cleaning the data
city = input("Enter a city name: ").strip().lower()

# Check which country the city belongs to
if city in india:
    print(f"The city '{city}' belongs to India.")
elif city in pakistan:
    print(f"The city '{city}' belongs to Pakistan.")
elif city in bangladesh:
    print(f"The city '{city}' belongs to Bangladesh.")
else:
    print("City not found in any of the lists.")
# Out:
# Enter a city name:  ChENNAi
# The city 'chennai' belongs to India.

# %%
# b. Write a program that asks the user to enter two cities and it tells you if they both are in the same country or not.
# For example if I enter mumbai and chennai, it will print "Both cities are in India",
# but if I enter mumbai and dhaka it should print "They don't belong to the same country".

india = ["mumbai", "banglore", "chennai", "delhi"]
pakistan = ["lahore", "karachi", "islamabad"]
bangladesh = ["dhaka", "khulna", "rangpur"]

# Cleaning the data
city1 = input("Enter the first city name: ").strip().lower()
city2 = input("Enter the second city name: ").strip().lower()

# Checking if both cities are in the same country or not!
if city1 in india and city2 in india:
    print("Both cities are in India.")
elif city1 in pakistan and city2 in pakistan:
    print("Both cities are in Pakistan.")
elif city1 in bangladesh and city2 in bangladesh:
    print("Both cities are in Bangladesh.")
else:
    print("They don't belong to the same country.")
# Out:
# Enter the first city name:  mumbai
# Enter the second city name:  delhi
# Both cities are in India.

# %% [markdown]
# ### Ques. 3 : Write a python program that can tell you if your sugar is normal or not. Normal fasting level sugar range is 80 to 100.
#     - Ask the user to enter his fasting sugar level.
#     - If it is below 80, then print that sugar is low.
#     - If it is above 100, then print that it is high
#     - Otherwise print that it is normal.

# %%
# Q3. Write a python program that can tell you if your sugar is normal or not. Normal fasting level sugar range is 80 to 100.
    # Ask the user to enter his fasting sugar level.
    # If it is below 80, then print that sugar is low.
    # If it is above 100, then print that it is high
    # Otherwise print that it is normal.

sugarLevel = float(input("Enter your fasting sugar level :"))

# Check the sugar level
if sugarLevel < 80:
    print("Sugar level is low")
elif sugarLevel > 100:
    print("Sugar level is high")
else:
    print("Sugar level is normal")
# Out:
# Enter your fasting sugar level : 85
# Sugar level is normal

# %% [markdown]
# ### Ques. 4 : Write a program which will accept a word and a number from the user. Check if the word starts with a vowel and the number is even and write appropriate conditions accordingly (Case sensitivity should not matter).
#     - Example :
#         Innoamtics, 6 --- both the conditions are satisfied
#         innomatics, 5--- at least one condition is satisfied
#         Ramya, 6--- at least one condition is satisfied
#         ramya , 5 --- none of the conditions are satisfied

# %%
# Cleaning the data
word = input("Enter a word :").strip()
number = int(input("Enter a number :"))

# Vowels check
vowels = 'aeiou'

# Checking if the word starts with a vowel
startLetter = word.lower()[0] in vowels

# Checking if the number is even
is_even = number % 2 == 0

if startLetter and is_even:
    print("Both the conditions are satisfied.")
elif startLetter or is_even:
    print("At least one condition is satisfied.")
else:
    print("None of the conditions are satisfied.")
# Out:
# Enter a word : Innoamtics
# Enter a number : 6
# Both the conditions are satisfied.
